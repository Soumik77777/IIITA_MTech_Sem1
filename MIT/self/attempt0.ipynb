# %% [markdown]
# # Linear Algebra : As Prof. Gilbert Strang Intended
# ### (or at least my interpretation)
#
# Professor Gilbert Strang is a legendary mathematician and educator whose teaching at MIT for 61 years transformed the way generations of students understand linear algebra. His representation of matrices is not merely a mathematical technique, but a form of art. His column picture and emphasis on subspaces reveal the structure hidden behind equations, ideas that continue to shape modern mathematics, computer science, machine learning, and the algorithm-driven world of today.
#
# [MIT OCW Spring 2005 Lecture Series](https://www.youtube.com/watch?v=hNDFwVVKVk0)
#
# **This is a thank-you note and an attempt to understand and present the underlying beauty of linear algebra the way he tried to teach it.**

# %% [markdown]
# ### - Soumik Bhattacharyya

# %%
# import modules

import numpy as np

import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D
from matplotlib.widgets import Slider

# %matplotlib widget

import importlib
import functions

# %%
importlib.reload(functions)

v1 = functions.get_vector()
v2 = functions.get_vector()

# %%
importlib.reload(functions)

functions.plot_vector(v1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
importlib.reload(functions)

# functions.span_one_vector_2d(v1)
# Out:
# <module 'functions' from '/media/soumik/storage/MTech/MIT/self/functions.py'>

# %%
importlib.reload(functions)

# functions.span_two_vectors_2d(v1, v2)

# change this to something that actually shows the whole R2 span
# we can first stretch a line, then change the coeff of other one, because current one does not mix up coeffs well
# Out:
# <module 'functions' from '/media/soumik/storage/MTech/MIT/self/functions.py'>

# %%
importlib.reload(functions)


# A, b = functions.get_system_2x2()

A = np.array([[2, 4], [3, 4]])
b = np.array([6, 7])

print("A =")
print(A)

print("b =")
print(b)
# Out:
# A =
# [[2 4]
#  [3 4]]
# b =
# [6 7]

# %%
importlib.reload(functions)

functions.plot_vectors_2x2(A, b)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# write the two methods, one: we find combinations of columns, two: we find intersection of the rows
#
# both are (can be) computationally expensive; if not for 2D, at least for 3D (or 1000000-D); but a lot of applications depend on matrices consisting of only 0s and 1s. the computationally expensive part remains similar for both approach, but for an easier to visualize matrix (0s and 1s), its easier to see the solution without doing the calculation.

# %%
importlib.reload(functions)

functions.plot_solution_2x2(A, b)
# Out:
# Solution:
# [1. 1.]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# A nice solution is not always guaranteed\
# by nice, i mean exactly one value for each x (x1, x2, ...)\
# in 2d, for a parallel case:

# %%
A = np.array([[2, 4], [3, 6]])
b = np.array([6, 9])

print("A =")
print(A)

print("b =")
print(b)

# %%
importlib.reload(functions)

functions.plot_vectors_2x2(A, b)

# %%
importlib.reload(functions)

functions.plot_solution_2x2(A, b)

# %% [markdown]
# parallel is the only bad case in 2D, either no solution or infinite solutions\
# then show in 3d how intersecting planes can have infinite solutions even when they are not parallel\
# till now show only values specified in code (not user)\
# in 3d, its difficult to see how planes combine, but is it?\
# take a matrix consisting of 0s and 1s. as that is a huge part of applications\
# show that, even not geometrically, by looking at a matrix, one can decide which columns contribute and which ones don't\
# to show that use text on matplotlib plot, use animation (built in ones may not be good, ask GPT once), generate a temp folder, temp figures, basically find out rows/cols that contribute and play those figs one by one, soething i did before
